# %%
# Credit Card Fraud Detection using Machine Learning and Python
# This model may be useful to banks to fight theft/fraud going on, on their user's account.

# Here we got 95% accuracy on Training data and 92% on Testing data which is awesome.
# Here we are going to see how we can build a Machine Learning model to differenciate real and fraudulent transactions.

# Time is in seconds.
# Here in Class 0 represents legit transaction and 1 represents fraudulent transaction.

# Here our data is processed using a principal component analysis function because they cannot give us the details about the transaction.
# It may contain a user's personal information that's why we have features in those kinds of numbers which doesn't make any sense for us.
# Those columns in our dataset are really important for our prediction.

# %%
# importing the dependencies

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# Loading our dataset

a = pd.read_csv('/content/drive/MyDrive/ML Datasets/credit-card.csv')
credit_card = pd.DataFrame(a)

# %%
# Dropping columns which aren't required

credit_card = credit_card.drop(columns='Time')

# %%
credit_card
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V21       V22  \
# ...

# %%
# Seeing the distribution of count class

credit_card['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
# Seperating legit and fraudulent transactions.
# 0 = Legit Transaction 1 = Fraudulent Transaction

legit = credit_card[credit_card.Class==0]

# %%
fraud = credit_card[credit_card.Class==1]

# %%
# Getting sample of 492 data from legit transaction

legit_sample = legit.sample(n=492)

# %%
# Putting legit_sample and fraud in our new dataframe

new_df = pd.concat([legit_sample, fraud], axis=0)

# %%
new_df
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 246596  1.886527 -1.786575  0.170520 -0.665632 -1.827595  0.645613 -1.762736
# 203251 -0.696655  1.104652  0.084441 -1.046435  1.192306 -0.676416  1.193634
# 153626 -1.251908  1.014314  0.819341 -0.477793 -0.416903  0.258817 -0.580714
# 140661 -0.687175 -0.240117  1.058203 -2.427235 -1.201069 -0.400761 -0.423202
# 17478   1.422569 -0.574552 -0.307302 -0.753679 -0.316422 -0.164764 -0.395290
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494 -0.882850
# 280143  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536 -1.413170
# 280149 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346 -2.234739
# 281144 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548 -2.208002
# 281674  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695  0.223050
#
# ...

# %%
# Splitting the labels and columns

X = new_df.drop(columns='Class')

# %%
Y = new_df['Class']

# %%
# Splitting the data into training and testing data

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, stratify=Y, random_state=2)

# %%
# Looking at the distribution after the split

print(X.shape, X_train.shape, X_test.shape)
# Out:
# (984, 29) (787, 29) (197, 29)

# %%
# Standardizing our data

scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
# The Standard Deviation is close to one for both of those.

X_train.std()
# Out:
# 1.0

# %%
X_test.std()
# Out:
# 1.031414758763866

# %%
# Importing our model

model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
# X train prediction

X_train_prediction = model.predict(X_train)
X_train_accuracyscore = accuracy_score(X_train_prediction, Y_train)

print(X_train_accuracyscore)
# Out:
# 0.951715374841169

# %%
# X test prediction

X_test_prediction = model.predict(X_test)
X_test_accuracyscore = accuracy_score(X_test_prediction, Y_test)

print(X_test_accuracyscore)
# Out:
# 0.9238578680203046

# %%
# Giving our own data and letting the model predict the outcome, which it did correctly everytime.

# %%
input_data = (-1.82429505976067,0.403326526860602,-1.99412200641801,2.75655816357726,-3.13906432572579,0.408185014718199,-1.20904511871624,1.09563435393431,-1.44722489217345,-3.95100289197434,2.56070020158284,-3.4119829114195,-0.781669619949492,-4.7327675351632,-0.433973654922625,-3.30608841178359,-4.23102187544855,-0.750809770409941,2.69080834203374,1.50368830479002,0.838760421033887,0.341727095787049,0.947506491293615,-0.145493002452622,0.0493257725258454,0.831065451615044,0.33242130393302,0.252712728641008,489.71)

# %%
input_data_numpy = np.asarray(input_data)

# %%
input_data_reshape = input_data_numpy.reshape(1,-1)

# %%
std = scaler.transform(input_data_reshape)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
prediction = model.predict(std)

# %%
print(prediction)
# Out:
# [1]

# %%
if prediction[0]==0:
  print('The Credit Card transaction is legit')
else:
  print('The Credit Card transaction is fraudulent')
# Out:
# The Credit Card transaction is fraudulent
